# %%
# Optional Colab setup
# If dependencies are missing, run this once:
# %pip install -r requirements.txt

print("Hakka Doctor notebook ready. Run the next cell to launch the maintained app.")

# %%
# Hakka Doctor maintained Gradio app launcher
#
# The Mandarin-Hakka interpretation logic now lives in:
# - HakkaDoctor_app.py for the Gradio interface
# - hakka_speech_toolkit/interpretation.py for testable matching logic
#
# This keeps the notebook lightweight and prevents stale duplicated app code.

from HakkaDoctor_app import demo

demo.launch(debug=True, share=True)
